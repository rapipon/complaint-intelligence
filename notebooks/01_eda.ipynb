# %%
import pandas as pd

df = pd.read_csv("../data/raw/complaints.csv")

# %%
df.shape
# Out:
# (500, 18)

# %%
df.head()
# Out:
#   date_received                                            product  \
# 0    10/16/2020  Credit reporting, credit repair services, or o...
# 1    10/24/2014                                   Credit reporting
# 2     3/14/2015                                   Credit reporting
# 3     7/13/2015                                    Debt collection
# 4     9/21/2018                                    Debt collection
#
#                               subproduct  \
# 0                 Credit repair services
# 1                                    NaN
# 2                                    NaN
# 3  Other (i.e. phone, health club, etc.)
# 4                             Other debt
#
#                                     issue       subissue  \
# 0                           Fraud or scam            NaN
# 1  Incorrect information on credit report  Account terms
# 2  Incorrect information on credit report  Account terms
# 3   Cont'd attempts collect debt not owed  Debt was paid
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date_received                 500 non-null    str
#  1   product                       500 non-null    str
#  2   subproduct                    494 non-null    str
#  3   issue                         500 non-null    str
#  4   subissue                      499 non-null    str
#  5   consumer_complaint_narrative  200 non-null    str
#  6   company_public_response       231 non-null    str
#  7   company_name                  500 non-null    str
#  8   state                         492 non-null    str
#  9   zip_code                      492 non-null    float64
#  10  tags                          63 non-null     str
#  11  consumer_consent_provided     382 non-null    str
#  12  submitted_via                 500 non-null    str
# ...

# %%
df.isna().sum()
df[("product")].value_counts()
# Out:
# product
# Debt collection                                                                 434
# Credit reporting, credit repair services, or other personal consumer reports     60
# Credit reporting                                                                  6
# Name: count, dtype: int64
